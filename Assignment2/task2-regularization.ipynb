# %% [markdown]
# # ECBM E4040 Assignment 2 - Task 2: Regularizations
#
# In this task, you are going to experiment with two popular regularization methods.
#
# ** Dropout:** In the last assignment, you have trained a shallow network and everything looked fine. However, when the network becomes larger and deeper, it will also become harder to train. The first potential problem is over-fitting, that is, the network overreacts to noise or random errors of the training data, while it fails to detect the underlying distribution pattern. It is more likely to occur when the model becomes complex and contains more trainable parameters. Dropout is a well-known method that can eliminate such effects. The core idea behind it is quite simple, ie., rather than updating all trainable parameters each time, it randomly selects a subset of parameters to update and keeps other parameters unaltered.
#
#
#
# ** Batch normalization:** Batch normalization makes it possible to train a deep network. When a network becomes deeper, the distribution of hidden neurons' values will also shift greatly, and that is one reason that makes it hard to train a deep neural network. Machine learning teaches that normalization is a good preprocessing method to deal with such a problem. So  batch normalization deploys a similar idea in the neural network. It re-normalizes the hidden values of each layer before transfering values to the next layer.
#
#
# * References
#     * https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
#     * https://arxiv.org/pdf/1502.03167.pdf
#     * https://www.tensorflow.org/api_docs/python/tf/contrib/layers/batch_norm
#     * https://github.com/tensorflow/tensorflow/blob/r1.3/tensorflow/contrib/layers/python/layers/layers.py
#     * https://www.tensorflow.org/api_docs/python/tf/nn/batch_normalization

# %%
% matplotlib inline
% load_ext autoreload
% autoreload 2

# Import modules
from __future__ import print_function
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from ecbm4040.cifar_utils import load_data

# %% [markdown]
# ## Load Data

# %%
# Load the raw CIFAR-10 data.
X_train, y_train, X_test, y_test = load_data()
X_val = X_train[:500,:]
y_val = y_train[:500]
X_train = X_train[500:2500,:]
y_train = y_train[500:2500]

mean_image = np.mean(X_train, axis=0).astype(np.float32)
X_train = X_train.astype(np.float32) - mean_image
X_val = X_val.astype(np.float32) - mean_image

# We've vectorized the data for you. That is, we flatten the 32×32×3 images into 1×3072 Numpy arrays.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# Training data shape:  (2000, 3072)
# Training labels shape:  (2000,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)

# %% [markdown]
# ## Part 1: Dropout

# %% [markdown]
# ### Implement dropout foward function
#
# <span style="color:red"><strong>TODO:</strong></span> Edit functions **dropout_forward** in **./ecbm4040/reg_funcs.py**. If the code is running correctly, you will see that the outputs of checking code should be close to each other. Also, if the function is correct, then the output mean should be close to each other.

# %%
x_in = np.random.randn(500, 500) + 10

# %%
from ecbm4040.reg_funcs import dropout_forward
from ecbm4040.reg_funcs import dropout_backward

p = 0.5
dropout_config = {"enabled": True, "keep_prob": p}
# feedforward
out, cache = dropout_forward(x=x_in, dropout_config=dropout_config, mode="train")
out_test, _ = dropout_forward(x=x_in, dropout_config=dropout_config, mode="test") 
# backward
dout = np.ones_like(x_in)
dx = dropout_backward(dout, cache)
#######################################
# Checking code. Don't change it.     #
#######################################
# Check forward correctness
print("mean_of_input = {}".format(p*np.mean(x_in)))
print("mean_of_out = {}".format(np.mean(out)))
print("mean_of_out_test = {}".format(np.mean(out_test)))
# Out:
# mean_of_input = 5.000599883001284
# mean_of_out = 4.98107424832419
# mean_of_out_test = 5.000599883001284

# %% [markdown]
# ### Experiments with MLP
#
# <span style="color:red"><strong>TODO:</strong></span>
#
# 1. Add dropout into MLP. Please review **loss**, **predict** function of class **MLP** in **./ecbm4040/neuralnets/mlp.py**, and understand how **dropout** is added into MLP.
#
# 2. Customize your own MLP network.Then, train networks with different **keep_prob**, like 0.1, 0.5, 0.7, 0.9, 1. If **keep_prob**==1, then the network become the normal MLP without dropout.
#
# 3. Plot the loss, train accuracy and valid accuracy curve.

# %%
from ecbm4040.neuralnets.mlp import MLP 
from ecbm4040.optimizers import AdamOptim

# %%
# Here is an example on how to collect loss and accuracy info
dropout_config = {"enabled":True, "keep_prob": 1}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_no_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.204, new learning rate = 0.00095
# epoch 2: valid acc = 0.234, new learning rate = 0.0009025
# epoch 3: valid acc = 0.324, new learning rate = 0.000857375
# epoch 4: valid acc = 0.326, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.36, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.344, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.372, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.374, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.346, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.35, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.37, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.36, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.396, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.372, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.37, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.36, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.354, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.338, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.334, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.386, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.1
dropout_config = {"enabled":True, "keep_prob": .1}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_1_dropout contains loss, train acc and valid acc history.
hist_1_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.216, new learning rate = 0.00095
# epoch 2: valid acc = 0.268, new learning rate = 0.0009025
# epoch 3: valid acc = 0.28, new learning rate = 0.000857375
# epoch 4: valid acc = 0.3, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.302, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.332, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.336, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.334, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.338, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.35, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.342, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.358, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.358, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.338, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.352, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.354, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.334, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.34, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.346, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.352, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.5
dropout_config = {"enabled":True, "keep_prob": .5}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_5_dropout contains loss, train acc and valid acc history.
hist_5_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.274, new learning rate = 0.00095
# epoch 2: valid acc = 0.274, new learning rate = 0.0009025
# epoch 3: valid acc = 0.31, new learning rate = 0.000857375
# epoch 4: valid acc = 0.336, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.33, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.35, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.35, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.35, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.36, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.376, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.368, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.388, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.376, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.376, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.37, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.38, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.38, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.384, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.382, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.39, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.7
dropout_config = {"enabled":True, "keep_prob": .7}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_7_dropout contains loss, train acc and valid acc history.
hist_7_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.234, new learning rate = 0.00095
# epoch 2: valid acc = 0.264, new learning rate = 0.0009025
# epoch 3: valid acc = 0.31, new learning rate = 0.000857375
# epoch 4: valid acc = 0.328, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.334, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.332, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.388, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.336, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.344, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.36, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.394, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.38, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.366, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.38, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.396, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.382, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.386, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.362, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.37, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.37, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.9
dropout_config = {"enabled":True, "keep_prob": .9}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_9_dropout contains loss, train acc and valid acc history.
hist_9_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.232, new learning rate = 0.00095
# epoch 2: valid acc = 0.258, new learning rate = 0.0009025
# epoch 3: valid acc = 0.294, new learning rate = 0.000857375
# epoch 4: valid acc = 0.348, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.354, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.352, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.38, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.358, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.33, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.328, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.348, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.386, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.372, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.348, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.376, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.348, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.372, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.388, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.394, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.384, new learning rate = 0.0003584859224085418

# %%
no_loss_hist, no_train_acc_hist, no_val_acc_hist = hist_no_dropout
loss_hist_1, train_acc_hist_1, val_acc_hist_1 = hist_1_dropout
loss_hist_5, train_acc_hist_5, val_acc_hist_5 = hist_5_dropout
loss_hist_7, train_acc_hist_7, val_acc_hist_7 = hist_7_dropout
loss_hist_9, train_acc_hist_9, val_acc_hist_9 = hist_9_dropout
# plot loss curve
plt.plot(no_loss_hist, label="Keep All")
plt.plot(loss_hist_1, label=".1 Keep Rate")
plt.plot(loss_hist_5, label=".5 Keep Rate")
plt.plot(loss_hist_7, label=".7 Keep Rate")
plt.plot(loss_hist_9, label=".9 Keep Rate")
plt.legend()
plt.show()

# %%
# plot train acc
plt.plot(no_train_acc_hist, label="Keep All")
plt.plot(train_acc_hist_1, label=".1 Keep Rate")
plt.plot(train_acc_hist_5, label=".5 Keep Rate")
plt.plot(train_acc_hist_7, label=".7 Keep Rate")
plt.plot(train_acc_hist_9, label=".9 Keep Rate")
plt.legend()
plt.show()

# %%
# plot val acc
plt.plot(no_val_acc_hist, label="Keep All")
plt.plot(val_acc_hist_1, label=".1 Keep Rate")
plt.plot(val_acc_hist_5, label=".5 Keep Rate")
plt.plot(val_acc_hist_7, label=".7 Keep Rate")
plt.plot(val_acc_hist_9, label=".9 Keep Rate")
plt.legend()
plt.show()

# %% [markdown]
# <span style="color:red"><strong>TODO:</strong></span> Describe what you find in this dropout experiment.

# %% [markdown]
# Answer: From this it can be seen that as the keep probabilities decrease, the training accuracy also decreases (as expected). However, once the validation accuracy is viewed, it can be seen that all of the validation accuracy values are much closer than their training accuracies. This is because of the issue of overfitting training data, which doesn't affect validation accuracy

# %% [markdown]
# ## Part 2: Batch Normalization

# %% [markdown]
# ### Implement batch normalization foward function
#
# <span style="color:red"><strong>TODO:</strong></span> Edit functions **bn_forward** in **./ecbm4040/reg_funcs.py**. If the code is running correctly, you will see that the outputs of checking code should be close to each other.

# %%
from ecbm4040.reg_funcs import bn_forward
from ecbm4040.reg_funcs import bn_backward

np.random.seed(4040)
N, D, H1, H2 = 200, 10, 5, 3
x_in = np.random.randn(N, D)
w1 = np.random.randn(D,H1)
w2 = np.random.randn(H1,H2)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)

# Before batch normalization
print("mean of a2: ", np.mean(a2, axis=0))
print("var of a2: ", np.var(a2, axis=0))

# Test "train mode" of forward function
# After batch normalization, the mean should be close to zero and var should be close to one. 
bn_config = {"epsilon":1e-5, "decay":0.9}
gamma = np.ones(H2)
beta = np.zeros(H2)
a2_bn, _ = bn_forward(a2, gamma, beta, bn_config, "train")
print("(train) mean of a2_bn: ", np.mean(a2_bn, axis=0))
print("(train) var of a2_bn: ", np.var(a2_bn, axis=0))
# Out:
# mean of a2:  [ 1.79186704 -1.67375614 -0.40317141]
# var of a2:  [19.78665186  3.35093598  6.67922991]
# (train) mean of a2_bn:  [4.68791672e-16 1.68198788e-16 1.57165947e-17]
# (train) var of a2_bn:  [0.99999949 0.99999702 0.9999985 ]

# %%
# Test "moving average" and "test mode" of forward function
# Then you are going to run the forward function under "training mode" for several times, 
# and the moving mean and moving var will be close to the real mean and var of the input data.
# Next, run the forward function under "test" mode and you will see that the mean and var of its 
# output will be also close to gamma, beta that you have set before.

bn_config = {"epsilon":1e-5, "decay":0.9}
gamma = np.ones(H2)
beta = np.zeros(H2)

# collect_data: for calculating real mean and var of a2 later.
collect_data = a2
for _ in range(100):
    x_in = np.random.randn(N, D)
    a2 = np.maximum(x_in.dot(w1),0).dot(w2)
    collect_data = np.concatenate((collect_data, a2), axis=0)
    bn_forward(a2, gamma, beta, bn_config, "train")

# compare moving_mean and moving_var with real mean and var.
# You should see that they are close to each other.
print("real mean of data: ", np.mean(collect_data, axis=0))
print("(real var of data: ", np.var(collect_data, axis=0))
print("moving mean of data: ", bn_config["moving_mean"])
print("(moving var of data: ", bn_config["moving_var"])

# "test mode" of forward function
# After bn_forward, the mean and var of output should be kind of close to gamma and beta.
x_in = np.random.randn(N, D)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)
print("*"*80)
print("mean of a2: ", np.mean(a2, axis=0))
print("var of a2: ", np.var(a2, axis=0))
a2_bn, _ = bn_forward(a2, gamma, beta, bn_config, "test")
print("(test) mean of a2_bn: ", np.mean(a2_bn, axis=0))
print("(test) var of a2_bn: ", np.var(a2_bn, axis=0))
# Out:
# real mean of data:  [ 1.666064   -1.60740475 -0.77169187]
# (real var of data:  [16.11643755  2.63509026  6.64151552]
# moving mean of data:  [ 1.68347874 -1.61213737 -0.78307063]
# (moving var of data:  [16.53922597  2.69276532  6.83992499]
# ********************************************************************************
# mean of a2:  [ 1.87970734 -1.62498121 -1.06240607]
# var of a2:  [13.59580536  2.85173111  5.97719192]
# (test) mean of a2_bn:  [ 0.04825081 -0.00782699 -0.10680708]
# (test) var of a2_bn:  [0.82203346 1.05903047 0.87386677]

# %%
# After verifying the forward function and save the bn_config.
x_in = np.random.randn(N, D)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)
da2_bn = np.ones_like(a2)
# Test backward function with tensorflow
#bn_config = {"eps":1e-5, "decay":0.9, "moving_mean":moving_mean, "moving_var":moving_var}
gamma = np.ones(H2)
beta = np.zeros(H2)
a2_bn, cache = bn_forward(a2, gamma, beta, bn_config, "test")
da2, dgamma, dbeta = bn_backward(da2_bn, cache)

# Checking code below.
a2_tf = tf.Variable(a2)
eps = bn_config["epsilon"]
mean_tf = bn_config["moving_mean"]
var_tf = bn_config["moving_var"]
gamma_tf = tf.Variable(gamma)
beta_tf = tf.Variable(beta)
a2_bn_tf = tf.nn.batch_normalization(a2_tf, mean_tf, var_tf, beta_tf, gamma_tf, eps)
# derive gradients
da2_tf = tf.gradients(a2_bn_tf, a2_tf)
dgamma_tf = tf.gradients(a2_bn_tf, gamma_tf)
dbeta_tf = tf.gradients(a2_bn_tf, beta_tf)

init = tf.global_variables_initializer()
tf_output = (a2_bn_tf, da2_tf[0], dgamma_tf[0], dbeta_tf[0])
with tf.Session() as sess:
    sess.run(init)
    a2_bn_check, da2_check, dgamma_check, dbeta_check = sess.run(tf_output)
    
# Make comparison
print("Is a2_bn correct? {}".format(np.allclose(a2_bn, a2_bn_check)))
print("Is da2 correct? {}".format(np.allclose(da2, da2_check)))
print("Is dgamma correct? {}".format(np.allclose(dgamma, dgamma_check)))
print("Is dbeta correct? {}".format(np.allclose(dbeta, dbeta_check)))
# Out:
# Is a2_bn correct? True
# Is da2 correct? True
# Is dgamma correct? True
# Is dbeta correct? True

# %% [markdown]
# ### Experiments with MLP
#
# <span style="color:red"><strong>TODO:</strong></span>
#
# 1. Add batch normalization into MLP. Please understand **loss**, **predict** function of class **MLP** in **./ecbm4040/neuralnets/mlp.py**
#
# 2. First create a shallow MLP like two-layer network like [100,10]. And train it without/with batch normalization. Plot the loss, train accuracy and valid accuracy curve.
#
# 3. Then, create a 5-layer MLP network like [100,50,50,50,10] and train the network with/without batch normalization. Again, Plot the loss, train accuracy and valid accuracy curve.
#
# 4. Make a comparison and describe what you have found in this experiment.

# %% [markdown]
# **Experiment on shallow MLP**

# %%
# Build a two-layer netowrk without batch normalization.
# Here is a demo.
use_bn = False
model = MLP(input_dim=3072, hidden_dims=[100], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_shallow_no_bn contains loss, train acc and valid acc history.
hist_shallow_no_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=5e-4, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.26, new learning rate = 0.000475
# epoch 2: valid acc = 0.29, new learning rate = 0.00045125
# epoch 3: valid acc = 0.348, new learning rate = 0.0004286875
# epoch 4: valid acc = 0.346, new learning rate = 0.00040725312499999993
# epoch 5: valid acc = 0.352, new learning rate = 0.0003868904687499999
# epoch 6: valid acc = 0.338, new learning rate = 0.0003675459453124999
# epoch 7: valid acc = 0.336, new learning rate = 0.00034916864804687486
# epoch 8: valid acc = 0.356, new learning rate = 0.0003317102156445311
# epoch 9: valid acc = 0.378, new learning rate = 0.0003151247048623045
# epoch 10: valid acc = 0.376, new learning rate = 0.00029936846961918924
# epoch 11: valid acc = 0.368, new learning rate = 0.00028440004613822977
# epoch 12: valid acc = 0.382, new learning rate = 0.00027018004383131826
# epoch 13: valid acc = 0.37, new learning rate = 0.00025667104163975234
# epoch 14: valid acc = 0.368, new learning rate = 0.00024383748955776472
# epoch 15: valid acc = 0.38, new learning rate = 0.00023164561507987649
# epoch 16: valid acc = 0.394, new learning rate = 0.00022006333432588265
# epoch 17: valid acc = 0.378, new learning rate = 0.00020906016760958852
# epoch 18: valid acc = 0.374, new learning rate = 0.00019860715922910907
# epoch 19: valid acc = 0.392, new learning rate = 0.0001886768012676536
# epoch 20: valid acc = 0.386, new learning rate = 0.0001792429612042709
# epoch 21: valid acc = 0.392, new learning rate = 0.00017028081314405735
# epoch 22: valid acc = 0.392, new learning rate = 0.00016176677248685447
# epoch 23: valid acc = 0.39, new learning rate = 0.00015367843386251173
# epoch 24: valid acc = 0.39, new learning rate = 0.00014599451216938612
# epoch 25: valid acc = 0.392, new learning rate = 0.00013869478656091682
# epoch 26: valid acc = 0.39, new learning rate = 0.00013176004723287096
# epoch 27: valid acc = 0.392, new learning rate = 0.0001251720448712274
# epoch 28: valid acc = 0.394, new learning rate = 0.00011891344262766602
# epoch 29: valid acc = 0.396, new learning rate = 0.00011296777049628272
# epoch 30: valid acc = 0.398, new learning rate = 0.00010731938197146858
# epoch 31: valid acc = 0.396, new learning rate = 0.00010195341287289515
# epoch 32: valid acc = 0.398, new learning rate = 9.685574222925039e-05
# epoch 33: valid acc = 0.398, new learning rate = 9.201295511778786e-05
# epoch 34: valid acc = 0.398, new learning rate = 8.741230736189846e-05
# epoch 35: valid acc = 0.398, new learning rate = 8.304169199380353e-05
# epoch 36: valid acc = 0.398, new learning rate = 7.888960739411335e-05
# epoch 37: valid acc = 0.398, new learning rate = 7.494512702440768e-05
# epoch 38: valid acc = 0.396, new learning rate = 7.119787067318729e-05
# epoch 39: valid acc = 0.396, new learning rate = 6.763797713952792e-05
# epoch 40: valid acc = 0.396, new learning rate = 6.425607828255152e-05
# epoch 41: valid acc = 0.398, new learning rate = 6.104327436842394e-05
# epoch 42: valid acc = 0.396, new learning rate = 5.799111065000274e-05
# epoch 43: valid acc = 0.396, new learning rate = 5.5091555117502596e-05
# epoch 44: valid acc = 0.396, new learning rate = 5.2336977361627463e-05
# epoch 45: valid acc = 0.396, new learning rate = 4.972012849354609e-05
# epoch 46: valid acc = 0.396, new learning rate = 4.723412206886878e-05
# epoch 47: valid acc = 0.396, new learning rate = 4.487241596542534e-05
# epoch 48: valid acc = 0.396, new learning rate = 4.262879516715407e-05
# epoch 49: valid acc = 0.396, new learning rate = 4.049735540879637e-05
# epoch 50: valid acc = 0.396, new learning rate = 3.847248763835655e-05

# %%
# TODO
# Build a two-layer netowrk with batch normalization. Remember to "use_bn".
use_bn = True
model = MLP(input_dim=3072, hidden_dims=[100], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_shallow_no_bn contains loss, train acc and valid acc history.
hist_shallow_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=5e-4, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.186, new learning rate = 0.000475
# epoch 2: valid acc = 0.25, new learning rate = 0.00045125
# epoch 3: valid acc = 0.256, new learning rate = 0.0004286875
# epoch 4: valid acc = 0.258, new learning rate = 0.00040725312499999993
# epoch 5: valid acc = 0.258, new learning rate = 0.0003868904687499999
# epoch 6: valid acc = 0.266, new learning rate = 0.0003675459453124999
# epoch 7: valid acc = 0.274, new learning rate = 0.00034916864804687486
# epoch 8: valid acc = 0.27, new learning rate = 0.0003317102156445311
# epoch 9: valid acc = 0.274, new learning rate = 0.0003151247048623045
# epoch 10: valid acc = 0.278, new learning rate = 0.00029936846961918924
# epoch 11: valid acc = 0.282, new learning rate = 0.00028440004613822977
# epoch 12: valid acc = 0.282, new learning rate = 0.00027018004383131826
# epoch 13: valid acc = 0.282, new learning rate = 0.00025667104163975234
# epoch 14: valid acc = 0.278, new learning rate = 0.00024383748955776472
# epoch 15: valid acc = 0.278, new learning rate = 0.00023164561507987649
# epoch 16: valid acc = 0.28, new learning rate = 0.00022006333432588265
# epoch 17: valid acc = 0.286, new learning rate = 0.00020906016760958852
# epoch 18: valid acc = 0.286, new learning rate = 0.00019860715922910907
# epoch 19: valid acc = 0.286, new learning rate = 0.0001886768012676536
# epoch 20: valid acc = 0.284, new learning rate = 0.0001792429612042709
# epoch 21: valid acc = 0.286, new learning rate = 0.00017028081314405735
# epoch 22: valid acc = 0.29, new learning rate = 0.00016176677248685447
# epoch 23: valid acc = 0.286, new learning rate = 0.00015367843386251173
# epoch 24: valid acc = 0.288, new learning rate = 0.00014599451216938612
# epoch 25: valid acc = 0.286, new learning rate = 0.00013869478656091682
# epoch 26: valid acc = 0.288, new learning rate = 0.00013176004723287096
# epoch 27: valid acc = 0.294, new learning rate = 0.0001251720448712274
# epoch 28: valid acc = 0.296, new learning rate = 0.00011891344262766602
# epoch 29: valid acc = 0.296, new learning rate = 0.00011296777049628272
# epoch 30: valid acc = 0.296, new learning rate = 0.00010731938197146858
# epoch 31: valid acc = 0.294, new learning rate = 0.00010195341287289515
# epoch 32: valid acc = 0.294, new learning rate = 9.685574222925039e-05
# epoch 33: valid acc = 0.292, new learning rate = 9.201295511778786e-05
# epoch 34: valid acc = 0.292, new learning rate = 8.741230736189846e-05
# epoch 35: valid acc = 0.29, new learning rate = 8.304169199380353e-05
# epoch 36: valid acc = 0.29, new learning rate = 7.888960739411335e-05
# epoch 37: valid acc = 0.292, new learning rate = 7.494512702440768e-05
# epoch 38: valid acc = 0.292, new learning rate = 7.119787067318729e-05
# epoch 39: valid acc = 0.292, new learning rate = 6.763797713952792e-05
# epoch 40: valid acc = 0.29, new learning rate = 6.425607828255152e-05
# epoch 41: valid acc = 0.29, new learning rate = 6.104327436842394e-05
# epoch 42: valid acc = 0.29, new learning rate = 5.799111065000274e-05
# epoch 43: valid acc = 0.29, new learning rate = 5.5091555117502596e-05
# epoch 44: valid acc = 0.29, new learning rate = 5.2336977361627463e-05
# epoch 45: valid acc = 0.29, new learning rate = 4.972012849354609e-05
# epoch 46: valid acc = 0.29, new learning rate = 4.723412206886878e-05
# epoch 47: valid acc = 0.29, new learning rate = 4.487241596542534e-05
# epoch 48: valid acc = 0.288, new learning rate = 4.262879516715407e-05
# epoch 49: valid acc = 0.29, new learning rate = 4.049735540879637e-05
# epoch 50: valid acc = 0.292, new learning rate = 3.847248763835655e-05

# %%
# Plot both results together and make a comparison. 
title_name = ["loss", "train acc", "val acc"]
_, axarr = plt.subplots(1,3, figsize=(15,5))
for i in range(3):
    axarr[i].plot(hist_shallow_no_bn[i], label="no_bn")
    axarr[i].plot(hist_shallow_bn[i], label="bn")
    axarr[i].legend(), axarr[i].set_title(title_name[i])
plt.show()

# %% [markdown]
# **Experiment on deep MLP**

# %%
# Build a deep 5-layer netowrk without batch normalization. Remember to "use_bn".
use_bn = False
model = MLP(input_dim=3072, hidden_dims=[100, 50, 50, 50], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_deep_no_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=1e-2, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.1, new learning rate = 0.0095
# epoch 2: valid acc = 0.1, new learning rate = 0.009025
# epoch 3: valid acc = 0.1, new learning rate = 0.00857375
# epoch 4: valid acc = 0.1, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.1, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.1, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.1, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.1, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.1, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.1, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.1, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.1, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.1, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.1, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.1, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.1, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.1, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.1, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.1, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.1, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.1, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.1, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.1, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.1, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.1, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.1, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.1, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.1, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.1, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.1, new learning rate = 0.0021463876394293723
# epoch 31: valid acc = 0.1, new learning rate = 0.0020390682574579037
# epoch 32: valid acc = 0.1, new learning rate = 0.0019371148445850085
# epoch 33: valid acc = 0.1, new learning rate = 0.0018402591023557579
# epoch 34: valid acc = 0.1, new learning rate = 0.0017482461472379698
# epoch 35: valid acc = 0.1, new learning rate = 0.0016608338398760713
# epoch 36: valid acc = 0.1, new learning rate = 0.0015777921478822676
# epoch 37: valid acc = 0.1, new learning rate = 0.001498902540488154
# epoch 38: valid acc = 0.1, new learning rate = 0.0014239574134637463
# epoch 39: valid acc = 0.1, new learning rate = 0.0013527595427905588
# epoch 40: valid acc = 0.1, new learning rate = 0.0012851215656510308
# epoch 41: valid acc = 0.1, new learning rate = 0.0012208654873684791
# epoch 42: valid acc = 0.1, new learning rate = 0.0011598222130000551
# epoch 43: valid acc = 0.1, new learning rate = 0.0011018311023500522
# epoch 44: valid acc = 0.1, new learning rate = 0.0010467395472325495
# epoch 45: valid acc = 0.1, new learning rate = 0.000994402569870922
# epoch 46: valid acc = 0.1, new learning rate = 0.0009446824413773759
# epoch 47: valid acc = 0.1, new learning rate = 0.0008974483193085071
# epoch 48: valid acc = 0.1, new learning rate = 0.0008525759033430817
# epoch 49: valid acc = 0.1, new learning rate = 0.0008099471081759276
# epoch 50: valid acc = 0.1, new learning rate = 0.0007694497527671312

# %%
# TODO
# Build a deep 5-layer netowrk with batch normalization. Remember to "use_bn".
use_bn = True
model = MLP(input_dim=3072, hidden_dims=[100, 50, 50, 50], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_deep_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=1e-2, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.136, new learning rate = 0.0095
# epoch 2: valid acc = 0.138, new learning rate = 0.009025
# epoch 3: valid acc = 0.14, new learning rate = 0.00857375
# epoch 4: valid acc = 0.168, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.17, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.158, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.162, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.172, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.168, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.164, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.164, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.168, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.168, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.17, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.168, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.166, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.166, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.17, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.166, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.168, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.17, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.168, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.166, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.17, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.166, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.168, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.164, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.166, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.168, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.164, new learning rate = 0.0021463876394293723
# epoch 31: valid acc = 0.168, new learning rate = 0.0020390682574579037
# epoch 32: valid acc = 0.168, new learning rate = 0.0019371148445850085
# epoch 33: valid acc = 0.168, new learning rate = 0.0018402591023557579
# epoch 34: valid acc = 0.168, new learning rate = 0.0017482461472379698
# epoch 35: valid acc = 0.168, new learning rate = 0.0016608338398760713
# epoch 36: valid acc = 0.168, new learning rate = 0.0015777921478822676
# epoch 37: valid acc = 0.174, new learning rate = 0.001498902540488154
# epoch 38: valid acc = 0.174, new learning rate = 0.0014239574134637463
# epoch 39: valid acc = 0.168, new learning rate = 0.0013527595427905588
# epoch 40: valid acc = 0.168, new learning rate = 0.0012851215656510308
# epoch 41: valid acc = 0.172, new learning rate = 0.0012208654873684791
# epoch 42: valid acc = 0.174, new learning rate = 0.0011598222130000551
# epoch 43: valid acc = 0.174, new learning rate = 0.0011018311023500522
# epoch 44: valid acc = 0.176, new learning rate = 0.0010467395472325495
# epoch 45: valid acc = 0.174, new learning rate = 0.000994402569870922
# epoch 46: valid acc = 0.176, new learning rate = 0.0009446824413773759
# epoch 47: valid acc = 0.178, new learning rate = 0.0008974483193085071
# epoch 48: valid acc = 0.174, new learning rate = 0.0008525759033430817
# epoch 49: valid acc = 0.172, new learning rate = 0.0008099471081759276
# epoch 50: valid acc = 0.174, new learning rate = 0.0007694497527671312

# %%
# Plot both results together and make a comparison. 
# Plot both results together and make a comparison. 
title_name = ["loss", "train acc", "val acc"]
_, axarr = plt.subplots(1,3, figsize=(15,5))
for i in range(3):
    axarr[i].plot(hist_deep_no_bn[i], label="no_bn")
    axarr[i].plot(hist_deep_bn[i], label="bn")
    axarr[i].legend(), axarr[i].set_title(title_name[i])
plt.show()

# %% [markdown]
# <span style="color:red"><strong>TODO:</strong></span> Describe what you find in this experiment.

# %% [markdown]
# Answer: This experiment shows that batch normalization helps to mitigate the issues of overfitting. In the shallow network, the training accuracy jumps to 100% with the non bin, while it is only 40% in the validation. The bin case stays much more constant. In the deep network, the bin allows the network to still learn while the no bin case is unable to learn.

# %% [markdown]
# ## Part 3: Dropout + Batch Normalization (optional)

# %%
# Create a deep netowrk with both dropout and batch normalization.

# %% [markdown]
# ## Reference
# * Weight Normalization: A Simple Reparameterization to Accelerate Training of Deep Neural Networks https://arxiv.org/abs/1602.07868
# * Highway netowrk https://arxiv.org/pdf/1505.00387.pdf
